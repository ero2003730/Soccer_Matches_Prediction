      "Ponte Preta": {"2015": 0.39, "2016": 0.40, "2017": 0.38},
      "Joinville": {"2015": 0.80},
      "Santa Cruz": {"2016": 0.25},
      "Vitória": {"2016": 0.33, "2017": 0.50, "2018": 0.33,},
      "Paraná": {"2018": 0.33},
      "Cuiabá": {"2021": 0.33, "2022": 0.44},
      "Figueirense": {"2015": 0.38, "2016": 0.22},
      "Juventude": {"2021": 0.11, "2022": 0.33 },
}
# Converter os dados do dicionário para um formato adequado para o mapa de calor
anos = range(2015, 2023)  # Intervalo de anos
times = list(dados.keys())  # Lista de times
acuracias = [[float(dados[time].get(str(ano), float('nan'))) for ano in anos] for time in times]

# Código do mapa de calor
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(acuracias, annot=True, fmt=".2f", cmap="YlGnBu", cbar=True,
            xticklabels=anos, yticklabels=times)
ax.set_xlabel("Ano")
ax.set_ylabel("Time")
ax.set_title("Acurácias Balanceadas")

# Exibir o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

times = dados.keys()
anos = range(2015, 2023)

for time in times:
    metricas = [dados[time].get(str(ano), float('nan')) for ano in anos]
    plt.plot(anos, metricas, label=time)

plt.xlabel('Ano')
plt.ylabel('Acurácia Balanceada')
plt.title('Comparação da Acurácia Balanceada ao longo do Tempo')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

times = dados.keys()
anos = range(2015, 2023)

fig, ax = plt.subplots()
width = 0.15
x = np.arange(len(anos))

for i, time in enumerate(times):
    valores = [dados[time].get(str(ano), float('nan')) for ano in anos]
    ax.bar(x + i * width, valores, width, label=time)

ax.set_xlabel('Ano')
ax.set_ylabel('Pontuação')
ax.set_title('Comparação das Métricas por Ano')
ax.set_xticks(x + (len(times) / 2) * width)
ax.set_xticklabels(anos)
ax.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

times = dados.keys()
anos = range(2015, 2023)

for time in times:
    valores = [dados[time].get(str(ano), float('nan')) for ano in anos]
    angles = np.linspace(0, 2 * np.pi, len(anos), endpoint=False).tolist()
    valores += valores[:1]
    angles += angles[:1]
    plt.polar(angles, valores, label=time)
    plt.fill(angles, valores, alpha=0.25)

plt.xticks(angles[:-1], anos)
plt.title('Comparação das Acurácias Balanceadas por Ano')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

times = dados.keys()
anos = list(range(2015, 2023))
metricas = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']

valores = [[dados[time].get(str(ano), 0) for ano in anos] for time in times]

plt.stackplot(anos, valores, labels=times)
plt.xlabel('Ano')
plt.ylabel('Acurácia Balanceada')
plt.title('Contribuição das Métricas por Time ao Longo dos Anos')
plt.legend()
plt.show()

# %%
# Dados das acurácias
anos = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
acuracia_media = [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1]

# Configurações do gráfico
plt.figure(figsize=(8, 6))
plt.bar(anos, acuracia_media, color='blue')

# Títulos e rótulos dos eixos
plt.title('Acurácia Média dos Modelos por Ano')
plt.xlabel('Ano')
plt.ylabel('Acurácia Média')

# Exibição do gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

years = range(2015, 2024)
accuracy = [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0]
balanced_accuracy = [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111, 1.0]
precision = [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755, 1.0]
recall = [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0]
f1_score = [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485, 1.0]

plt.plot(years, accuracy, label='Accuracy')
plt.plot(years, balanced_accuracy, label='Balanced Accuracy')
plt.plot(years, precision, label='Precision')
plt.plot(years, recall, label='Recall')
plt.plot(years, f1_score, label='F1 Score')

plt.xlabel('Ano')
plt.ylabel('Métricas')
plt.title('Evolução das Métricas ao longo do tempo')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']
years = range(2015, 2024)
values = [
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111, 1.0],
    [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755, 1.0],
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485, 1.0]
]

bar_width = 0.15
index = np.arange(len(years))

for i in range(len(metrics)):
    plt.bar(index + i * bar_width, values[i], bar_width, label=metrics[i])

plt.xlabel('Ano')
plt.ylabel('Métricas')
plt.title('Comparação das Métricas por Ano')
plt.xticks(index + bar_width * 2, years)
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']
years = range(2015, 2023)
values = [
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429],
    [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111],
    [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755],
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429],
    [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485]
]

angles = np.linspace(0, 2 * np.pi, len(metrics), endpoint=False).tolist()
values = [val[:len(angles)] for val in values]

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})
for i, year in enumerate(years[:len(values)]):  # Ajuste para percorrer até o tamanho de values
    ax.plot(angles, values[i], 'o-', linewidth=2, label=year)
    ax.fill(angles, values[i], alpha=0.25)

ax.set_xticks(angles)
ax.set_xticklabels(metrics)
ax.set_yticklabels([])
ax.legend(loc='upper right')

plt.title('Comparação das Métricas por Ano')

plt.show()

# %%
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']
years = range(2015, 2024)
values = [
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111, 1.0],
    [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755, 1.0],
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485, 1.0]
]

plt.boxplot(values, labels=metrics)
plt.xlabel('Métricas')
plt.ylabel('Valores')
plt.title('Distribuição das Métricas por Ano')

plt.show()

# %%
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']
years = range(2015, 2024)
values = [
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111, 1.0],
    [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755, 1.0],
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485, 1.0]
]

plt.scatter(values[0], values[1])
plt.xlabel(metrics[0])
plt.ylabel(metrics[1])
plt.title('Comparação de Métricas')

for i, year in enumerate(years):
    plt.text(values[0][i], values[1][i], str(year))

plt.show()

# %%
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Balanced Accuracy', 'Precision', 'Recall', 'F1 Score']
years = range(2015, 2024)
values = [
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.54798, 0.539394, 0.461376, 0.444444, 0.666667, 0.527778, 0.656746, 0.511111, 1.0],
    [0.539683, 0.670068, 0.47619, 0.571429, 0.689394, 0.671429, 0.670996, 0.578755, 1.0],
    [0.571429, 0.619048, 0.47619, 0.666667, 0.619048, 0.619048, 0.666667, 0.571429, 1.0],
    [0.542167, 0.608435, 0.47619, 0.604082, 0.603965, 0.635714, 0.655161, 0.553485, 1.0]
]

plt.stackplot(years, values, labels=metrics)
plt.xlabel('Ano')
plt.ylabel('Valores')
plt.title('Contribuição das Métricas ao longo do tempo')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

#
      "Chapecoense": {"2015": 0.61, "2016": 0.33, "2017": 0.33, "2018": 0.50, "2019": 0.00, "2021": 0.33},
      "América-MG": {"2016": 0.20, "2018": 0.22, "2021": 0.33, "2022": 0.00},
      "Ponte Preta": {"2015": 0.39, "2016": 0.40, "2017": 0.38},
      "Joinville": {"2015": 0.80},
      "Santa Cruz": {"2016": 0.25},
      "Vitória": {"2016": 0.33, "2017": 0.50, "2018": 0.33,},
      "Paraná": {"2018": 0.33},
      "Cuiabá": {"2021": 0.33, "2022": 0.44},
      "Figueirense": {"2015": 0.38, "2016": 0.22},
      "Juventude": {"2021": 0.11, "2022": 0.33 },
}

# Dicionário de campeonato ajustado
championship_dict_adjusted = {
    "Accuracy": {"2015": 0.571429, "2016": 0.619048, "2017": 0.47619, "2018": 0.666667, "2019": 0.619048, "2020": 0.619048, "2021": 0.666667, "2022": 0.571429},
    "Balanced Accuracy": {"2015": 0.54798, "2016": 0.539394, "2017": 0.461376, "2018": 0.444444, "2019": 0.666667, "2020": 0.527778, "2021": 0.656746, "2022": 0.511111},
    "Precision": {"2015": 0.539683, "2016": 0.670068, "2017": 0.47619, "2018": 0.571429, "2019": 0.689394, "2020": 0.671429, "2021": 0.670996, "2022": 0.578755},
    "Recall": {"2015": 0.571429, "2016": 0.619048, "2017": 0.47619, "2018": 0.666667, "2019": 0.619048, "2020": 0.619048, "2021": 0.666667, "2022": 0.571429},
    "F1 Score": {"2015": 0.542167, "2016": 0.608435, "2017": 0.47619, "2018": 0.604082, "2019": 0.603965, "2020": 0.635714, "2021": 0.655161, "2022": 0.553485},
}

# Converte os dicionários em DataFrames
team_df = pd.DataFrame(team_dict).transpose()
championship_df = pd.DataFrame(championship_dict_adjusted).transpose()

# Converte as colunas (que são os anos) para inteiros
team_df.columns = team_df.columns.astype(int)
championship_df.columns = championship_df.columns.astype(int)

# Ordena os dataframes pelas colunas
team_df = team_df.sort_index(axis=1)
championship_df = championship_df.sort_index(axis=1)

# Cria subplots para cada equipe
fig, axs = plt.subplots(len(team_df), 1, figsize=(8, len(team_df)*2), sharex=True)
for i, (team, row) in enumerate(team_df.iterrows()):
    ax = axs[i]
    ax.plot(row, label=f"{team} Acurácia Balanceada")
    ax.plot(championship_df.loc['Balanced Accuracy'], label="Acurácia Balanceada do Campeonato", linestyle='--')
    ax.legend()
    ax.set_title(team)

# Configuração final do gráfico
plt.xlabel('Ano')
plt.xlim(2015, 2022)  # Define os limites do eixo X
plt.xticks(range(2015, 2023))  # Define as marcas do eixo X
plt.tight_layout()
plt.show()

# %%
# Classificação das equipes para 2015
classification_2015 = [
    "Corinthians",
    "Atlético-MG",
    "Grêmio",
    "São Paulo",
    "Internacional",
    "Sport Recife",
    "Santos",
    "Cruzeiro",
    "Palmeiras",
    "Athletico-PR",
    "Ponte Preta",
    "Flamengo",
    "Fluminense",
    "Chapecoense",
    "Coritiba",
    "Figueirense",
    "Avaí",
    "Vasco",
    "Goiás",
    "Joinville"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2015:
    try:
        accuracy = team_dict[team]["2015"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2015, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Corinthians (0.5)
# Atlético-MG (0.5)
# Grêmio (0.39)
# São Paulo (0.17)
# Internacional (0.39)
# Sport Recife (0.17)
# Santos (0.62)
# Cruzeiro (0.44)
# Palmeiras (0.1)
# Athletico-PR (0.33)
# Ponte Preta (0.39)
# Flamengo (0.22)
# Fluminense (0.25)
# Chapecoense (0.61)
# Coritiba (0.28)
# Figueirense (0.38)
# Avaí (0.5)
# Vasco (0.11)
# Goiás (0.11)
# Joinville (0.8)

# %%
# Classificação das equipes para 2016
classification_2016 = [
    "Palmeiras",
    "Santos",
    "Flamengo",
    "Atlético-MG",
    "Botafogo",
    "Athletico-PR",
    "Corinthians",
    "Ponte Preta",
    "Grêmio",
    "São Paulo",
    "Chapecoense",
    "Cruzeiro",
    "Fluminense",
    "Sport Recife",
    "Coritiba",
    "Vitória",
    "Internacional",
    "Figueirense",
    "Santa Cruz",
    "América-MG"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2016:
    try:
        accuracy = team_dict[team]["2016"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2016, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Palmeiras (0.33)
# Santos (0.33)
# Flamengo (0.28)
# Atlético-MG (0.3)
# Botafogo (0.11)
# Athletico-PR (0.58)
# Corinthians (0.44)
# Ponte Preta (0.4)
# Grêmio (0.25)
# São Paulo (0.22)
# Chapecoense (0.33)
# Cruzeiro (0.0)
# Fluminense (0.17)
# Sport Recife (0.3)
# Coritiba (0.39)
# Vitória (0.33)
# Internacional (0.5)
# Figueirense (0.22)
# Santa Cruz (0.25)
# América-MG (0.2)

# %%
# Classificação das equipes para 2017
classification_2017 = [
    "Corinthians",
    "Palmeiras",
    "Santos",
    "Grêmio",
    "Cruzeiro",
    "Flamengo",
    "Vasco",
    "Chapecoense",
    "Atlético-MG",
    "Botafogo",
    "Athletico-PR",
    "Bahia",
    "São Paulo",
    "Fluminense",
    "Sport Recife",
    "Vitória",
    "Coritiba",
    "Avaí",
    "Ponte Preta",
    "Atlético-GO"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2017:
    try:
        accuracy = team_dict[team]["2017"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2017, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Corinthians (0.33)
# Palmeiras (0.33)
# Santos (0.3)
# Grêmio (0.17)
# Cruzeiro (0.33)
# Flamengo (0.5)
# Vasco (0.42)
# Chapecoense (0.33)
# Atlético-MG (0.42)
# Botafogo (0.78)
# Athletico-PR (0.67)
# Bahia (0.22)
# São Paulo (0.33)
# Fluminense (0.33)
# Sport Recife (0.33)
# Vitória (0.5)
# Coritiba (0.33)
# Avaí (0.33)
# Ponte Preta (0.38)
# Atlético-GO (0.5)

# %%
# Classificação das equipes para 2018
classification_2018 = [
    "Palmeiras",
    "Flamengo",
    "Internacional",
    "Grêmio",
    "São Paulo",
    "Atlético-MG",
    "Athletico-PR",
    "Cruzeiro",
    "Botafogo",
    "Santos",
    "Bahia",
    "Fluminense",
    "Corinthians",
    "Chapecoense",
    "Ceará",
    "Vasco",
    "América-MG",
    "Sport Recife",
    "Vitória",
    "Paraná"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2018:
    try:
        accuracy = team_dict[team]["2018"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2018, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Palmeiras (0.3)
# Flamengo (0.33)
# Internacional (0.25)
# Grêmio (0.5)
# São Paulo (0.33)
# Atlético-MG (0.25)
# Athletico-PR (0.25)
# Cruzeiro (0.67)
# Botafogo (0.5)
# Santos (0.33)
# Bahia (0.33)
# Fluminense (0.75)
# Corinthians (0.58)
# Chapecoense (0.5)
# Ceará (0.62)
# Vasco (0.22)
# América-MG (0.22)
# Sport Recife (0.38)
# Vitória (0.33)
# Paraná (0.33)

# %%
# Classificação das equipes para 2019
classification_2019 = [
    "Flamengo",
    "Santos",
    "Palmeiras",
    "Grêmio",
    "Athletico-PR",
    "São Paulo",
    "Internacional",
    "Corinthians",
    "Fortaleza",
    "Goiás",
    "Bahia",
    "Vasco",
    "Atlético-MG",
    "Fluminense",
    "Botafogo",
    "Ceará",
    "Cruzeiro",
    "CSA",
    "Chapecoense",
    "Avaí"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2019:
    try:
        accuracy = team_dict[team]["2019"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2019, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Flamengo (0.83)
# Santos (0.11)
# Palmeiras (0.67)
# Grêmio (0.5)
# Athletico-PR (0.39)
# São Paulo (0.62)
# Internacional (0.5)
# Corinthians (0.33)
# Fortaleza (0.33)
# Goiás (0.22)
# Bahia (0.33)
# Vasco (0.42)
# Atlético-MG (0.61)
# Fluminense (0.72)
# Botafogo (0.58)
# Ceará (0.9)
# Cruzeiro (0.5)
# CSA (0.11)
# Chapecoense (0.0)
# Avaí (0.39)

# %%
# Classificação das equipes para 2020
classification_2020 = [
    "Flamengo",
    "Internacional",
    "Atlético-MG",
    "São Paulo",
    "Fluminense",
    "Grêmio",
    "Palmeiras",
    "Santos",
    "Athletico-PR",
    "Bragantino",
    "Ceará",
    "Corinthians",
    "Atlético-GO",
    "Bahia",
    "Sport Recife",
    "Fortaleza",
    "Vasco",
    "Goiás",
    "Coritiba",
    "Botafogo"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2020:
    try:
        accuracy = team_dict[team]["2020"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2020, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)

# %%
# Classificação das equipes para 2021
classification_2021 = [
    "Atlético-MG",
    "Flamengo",
    "Palmeiras",
    "Fortaleza",
    "Corinthians",
    "Bragantino",
    "Fluminense",
    "América-MG",
    "Atlético-GO",
    "Santos",
    "Ceará",
    "Internacional",
    "São Paulo",
    "Athletico-PR",
    "Cuiabá",
    "Juventude",
    "Grêmio",
    "Bahia",
    "Sport Recife",
    "Chapecoense"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2021:
    try:
        accuracy = team_dict[team]["2021"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2021, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Atlético-MG (0.0)
# Flamengo (0.33)
# Palmeiras (0.33)
# Fortaleza (0.33)
# Corinthians (0.33)
# Bragantino (0.33)
# Fluminense (0.6)
# América-MG (0.33)
# Atlético-GO (0.33)
# Santos (0.44)
# Ceará (0.5)
# Internacional (0.0)
# São Paulo (0.33)
# Athletico-PR (0.17)
# Cuiabá (0.33)
# Juventude (0.11)
# Grêmio (0.0)
# Bahia (0.33)
# Sport Recife (0.44)
# Chapecoense (0.33)

# %%
# Classificação das equipes para 2022
classification_2022 = [
    "Palmeiras",
    "Internacional",
    "Fluminense",
    "Corinthians",
    "Flamengo",
    "Athletico-PR",
    "Atlético-MG",
    "Fortaleza",
    "São Paulo",
    "América-MG",
    "Botafogo",
    "Santos",
    "Goiás",
    "Bragantino",
    "Coritiba",
    "Cuiabá",
    "Ceará",
    "Atlético-GO",
    "Avaí",
    "Juventude"
]

# Mapeia a acurácia balanceada para cada equipe na classificação
classification_with_accuracy = {}
for team in classification_2022:
    try:
        accuracy = team_dict[team]["2022"]
    except KeyError:  # Se a equipe não tiver uma entrada para 2022, use um valor padrão
        accuracy = 0
    classification_with_accuracy[f"{team} ({accuracy})"] = accuracy

# Exibe a classificação com acurácia
for team, accuracy in classification_with_accuracy.items():
    print(team)
# Out:
# Palmeiras (0.17)
# Internacional (0.33)
# Fluminense (0.0)
# Corinthians (0.33)
# Flamengo (0.44)
# Athletico-PR (0.5)
# Atlético-MG (0.67)
# Fortaleza (0.33)
# São Paulo (0.22)
# América-MG (0.0)
# Botafogo (0.0)
# Santos (0.0)
# Goiás (0.33)
# Bragantino (0.12)
# Coritiba (0.6)
# Cuiabá (0.44)
# Ceará (0.3)
# Atlético-GO (0.67)
# Avaí (0.33)
# Juventude (0.33)
